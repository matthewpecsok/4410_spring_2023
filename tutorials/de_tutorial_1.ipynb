# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewpecsok/4410_spring_2023/blob/main/tutorials/de_tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install --upgrade ipython
# !pip -q install --upgrade ipython-sql

# %%
import pandas as pd
import sqlite3

# %%
# !wget -O movies.db https://github.com/matthewpecsok/data_engineering/blob/main/data/movies.sqlite?raw=true

con = sqlite3.connect('movies.db')

# %load_ext sql
# %sql sqlite:///movies.db

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# Out:
# --2023-05-19 16:03:07--  https://github.com/matthewpecsok/data_engineering/blob/main/data/movies.sqlite?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/matthewpecsok/data_engineering/raw/main/data/movies.sqlite [following]
# --2023-05-19 16:03:07--  https://github.com/matthewpecsok/data_engineering/raw/main/data/movies.sqlite
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/matthewpecsok/data_engineering/main/data/movies.sqlite [following]
# --2023-05-19 16:03:07--  https://raw.githubusercontent.com/matthewpecsok/data_engineering/main/data/movies.sqlite
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2527232 (2.4M) [application/octet-stream]
# Saving to: ‘movies.db’
#
# movies.db           100%[===================>]   2.41M  --.-KB/s    in 0.06s
#
# 2023-05-19 16:03:07 (37.4 MB/s) - ‘movies.db’ saved [2527232/2527232]
#
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql SELECT name, sql FROM sqlite_master
# WHERE type='table'
# ORDER BY name;
# Out:
#               name                                                sql
# 0        directors  CREATE TABLE `directors` (\n`name` TEXT,\n`id`...
# 1           movies  CREATE TABLE `movies` (\n`id` INTEGER PRIMARY ...
# 2  sqlite_sequence             CREATE TABLE sqlite_sequence(name,seq)

# %%
# %sql select count(1) from movies
# Out:
#    count(1)
# 0      4773

# %%
# %sql select count(1) as director_count from directors
# Out:
#    director_count
# 0            2349

# %%
# %sql select * from movies limit 5
# Out:
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
#
#   release_date     revenue                                     title  \
# 0   2009-12-10  2787965087                                    Avatar
# 1   2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2   2015-10-26   880674609                                   Spectre
# 3   2012-07-16  1084939099                     The Dark Knight Rises
# 4   2012-03-07   284139100                               John Carter
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline     uid  director_id
# 0                     Enter the World of Pandora.   19995         4762
# 1  At the end of the world, the adventure begins.     285         4763
# 2                           A Plan No One Escapes  206647         4764
# 3                                 The Legend Ends   49026         4765
# 4            Lost in our world, found in another.   49529         4766

# %%
# %sql select * from directors limit 5
# Out:
#                 name    id  gender   uid department
# 0      James Cameron  4762       2  2710  Directing
# 1     Gore Verbinski  4763       2  1704  Directing
# 2         Sam Mendes  4764       2    39  Directing
# 3  Christopher Nolan  4765       2   525  Directing
# 4     Andrew Stanton  4766       2     7  Directing

# %%
# %sql select max(budget),max(revenue) from movies
# Out:
#    max(budget)  max(revenue)
# 0    380000000    2787965087

# %%
# %sql select budget,title from movies order by budget desc limit 10
# Out:
#       budget                                        title
# 0  380000000  Pirates of the Caribbean: On Stranger Tides
# 1  300000000     Pirates of the Caribbean: At World's End
# 2  280000000                      Avengers: Age of Ultron
# 3  270000000                             Superman Returns
# 4  260000000                                  John Carter
# 5  260000000                                      Tangled
# 6  258000000                                 Spider-Man 3
# 7  255000000                              The Lone Ranger
# 8  250000000                        The Dark Knight Rises
# 9  250000000       Harry Potter and the Half-Blood Prince

# %%
# %sql select min(release_date),max(release_date),max(release_date) - min(release_date) as years_of_releases from movies
# Out:
#   min(release_date) max(release_date)  years_of_releases
# 0        1916-09-04        2017-02-03                101

# %%
cursor = con.cursor()

# %%
# %%sql select
#
# avg(budget),
# avg(revenue),
# director_id
#
# from movies
#
# group by director_id order by (avg(budget)) desc
# limit 5
# Out:
#     avg(budget)  avg(revenue)  director_id
# 0  2.600000e+08  5.917949e+08         4768
# 1  2.000000e+08  1.066970e+09         4792
# 2  2.000000e+08  7.435596e+08         4787
# 3  1.933333e+08  7.429717e+08         4770
# 4  1.850000e+08  5.389832e+08         4801

# %%
# %sql select distinct(department) from directors
# Out:
#   department
# 0  Directing

# %%
# %%sql select *
#
# from movies m
# left join directors d on m.director_id = d.id
#
#
# limit 80
# Out:
#        id                            original_title     budget  popularity  \
# 0   43597                                    Avatar  237000000         150
# 1   43598  Pirates of the Caribbean: At World's End  300000000         139
# 2   43599                                   Spectre  245000000         107
# 3   43600                     The Dark Knight Rises  250000000         112
# 4   43601                               John Carter  260000000          43
# ..    ...                                       ...        ...         ...
# 75  43672                                Waterworld  175000000          44
# 76  43673               G.I. Joe: The Rise of Cobra  175000000          32
# 77  43674                                Inside Out  175000000         128
# 78  43675                           The Jungle Book  175000000          94
# 79  43676                                Iron Man 2  200000000          77
#
#    release_date     revenue                                     title  \
# 0    2009-12-10  2787965087                                    Avatar
# 1    2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2    2015-10-26   880674609                                   Spectre
# 3    2012-07-16  1084939099                     The Dark Knight Rises
# 4    2012-03-07   284139100                               John Carter
# ..          ...         ...                                       ...
# 75   1995-07-28   264218220                                Waterworld
# 76   2009-08-04   302469017               G.I. Joe: The Rise of Cobra
# 77   2015-06-09   857611174                                Inside Out
# 78   2016-04-07   966550600                           The Jungle Book
# 79   2010-04-28   623933331                                Iron Man 2
#
#     vote_average  vote_count  \
# 0            7.2       11800
# 1            6.9        4500
# 2            6.3        4466
# 3            7.6        9106
# 4            6.1        2124
# ..           ...         ...
# 75           5.9         992
# 76           5.6        1962
# 77           8.0        6560
# 78           6.7        2892
# 79           6.6        6849
#
#                                              overview  \
# 0   In the 22nd century, a paraplegic Marine is di...
# 1   Captain Barbossa, long believed to be dead, ha...
# 2   A cryptic message from Bond’s past sends him o...
# 3   Following the death of District Attorney Harve...
# 4   John Carter is a war-weary, former military ca...
# ..                                                ...
# 75  In a futuristic world where the polar ice caps...
# 76  From the Egyptian desert to deep below the pol...
# 77  Growing up can be a bumpy road, and it's no ex...
# 78  After a threat from the tiger Shere Khan force...
# 79  With the world now aware of his dual life as t...
#
#                                               tagline     uid  director_id  \
# 0                         Enter the World of Pandora.   19995         4762
# 1      At the end of the world, the adventure begins.     285         4763
# 2                               A Plan No One Escapes  206647         4764
# 3                                     The Legend Ends   49026         4765
# 4                Lost in our world, found in another.   49529         4766
# ..                                                ...     ...          ...
# 75  Beyond the horizon lies the secret to a new be...    9804         4814
# 76                   When all else fails, they don't.   14869         4815
# 77           Meet the little voices inside your head.  150540         4806
# 78                                               None  278927         4808
# 79  It's not the armor that makes the hero, but th...   10138         4808
#
#                  name    id  gender    uid department
# 0       James Cameron  4762       2   2710  Directing
# 1      Gore Verbinski  4763       2   1704  Directing
# 2          Sam Mendes  4764       2     39  Directing
# 3   Christopher Nolan  4765       2    525  Directing
# 4      Andrew Stanton  4766       2      7  Directing
# ..                ...   ...     ...    ...        ...
# 75     Kevin Reynolds  4814       0   8300  Directing
# 76    Stephen Sommers  4815       2   7775  Directing
# 77        Pete Docter  4806       2  12890  Directing
# 78        Jon Favreau  4808       2  15277  Directing
# 79        Jon Favreau  4808       2  15277  Directing
#
# [80 rows x 18 columns]

# %%
# %%sql select
#
# avg(budget),
# avg(revenue),
# director_id,
# name,
# count(1) as movie_count
#
# from movies m
# left join directors d on m.director_id = d.id
#
# group by director_id
# having(count(1)>3)
# order by avg(budget)
# desc
# limit 3
# Out:
#     avg(budget)  avg(revenue)  director_id            name  movie_count
# 0  1.635000e+08  5.272613e+08         4766  Andrew Stanton            4
# 1  1.581429e+08  4.538591e+08         4763  Gore Verbinski            7
# 2  1.448750e+08  3.510294e+08         4772    Bryan Singer            8

# %%
# %sql select * from movies where director_id = 4768
# Out:
#       id original_title     budget  popularity release_date    revenue  \
# 0  43603        Tangled  260000000          48   2010-11-24  591794936
#
#      title  vote_average  vote_count  \
# 0  Tangled           7.4        3330
#
#                                             overview  \
# 0  When the kingdom's most wanted-and most charmi...
#
#                                     tagline    uid  director_id
# 0  They're taking adventure to new lengths.  38757         4768

# %%
# %sql select * from movies where director_id not in (select id from directors)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
